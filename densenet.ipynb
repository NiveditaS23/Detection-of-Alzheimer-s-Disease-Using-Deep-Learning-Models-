# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import skimage.io
import os 
import tqdm
import glob 

from tqdm import tqdm
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.color import gray2rgb
from tensorflow.keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPool2D, Conv2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications.densenet import DenseNet169
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import keras.backend as K

# %%
# Define a single data generator with augmentation and validation split
datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    validation_split=0.2
)

# Training dataset (80% of data)
train_dataset = datagen.flow_from_directory(
    directory= r"C:\Users\Shubhankar\Downloads\archive (3)\Alzheimer_MRI_4_classes_dataset",
    target_size=(224, 224),
    batch_size=128,
    class_mode='categorical',
    subset='training',
    shuffle=True
)

# Validation dataset (20% of data)
valid_dataset = datagen.flow_from_directory(
    directory= r"C:\Users\Shubhankar\Downloads\archive (3)\Alzheimer_MRI_4_classes_dataset",
    target_size=(224, 224),
    batch_size=128,
    class_mode='categorical',
    subset='validation',
    shuffle=True
)
# Out:
# Found 5121 images belonging to 4 classes.
# Found 1279 images belonging to 4 classes.

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 5, figsize=(20,20))

for i in tqdm(range(0,5)):
    rand1 = np.random.randint(len(train_dataset))
    rand2 = np.random.randint(100)
    ax[i].imshow(train_dataset[rand1][0][rand2])
    ax[i].axis('off')
    a = train_dataset[rand1][1][rand2]
    if a[0] == 1:
        ax[i].set_title('Mild Dementia')
    elif a[1] == 1:
        ax[i].set_title('Moderate Dementia')
    elif a[2] == 1:
        ax[i].set_title('Non Demetia')
    elif a[3] == 1:
        ax[i].set_title('Very Mild Dementia')
# Out:
# 100%|██████████| 5/5 [00:12<00:00,  2.57s/it]

# %%
# Model Initialization

base_model = DenseNet169(input_shape=(224,224,3), 
                         include_top=False,
                         weights="imagenet")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet169_weights_tf_dim_ordering_tf_kernels_notop.h5
# 51877672/51877672 ━━━━━━━━━━━━━━━━━━━━ 9s 0us/step

# %%
# Freezing Layers

for layer in base_model.layers:
    layer.trainable=False

# %%
# Building Model

model=Sequential()
model.add(base_model)
model.add(Dropout(0.5))
model.add(Flatten())
model.add(BatchNormalization())
model.add(Dense(2048,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1024,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(4,activation='softmax'))

# %%
# Summary

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ densenet169 (Functional)        │ (None, 7, 7, 1664)     │    12,642,880 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 7, 7, 1664)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 81536)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 81536)          │       326,144 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 2048)           │   166,987,776 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 2048)           │         8,192 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1024)           │     2,098,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 4)              │         4,100 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 182,071,364 (694.55 MB)
#  Trainable params: 169,259,268 (645.67 MB)
#  Non-trainable params: 12,812,096 (48.87 MB)

# %%
def f1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
import tensorflow as tf

OPT = tf.keras.optimizers.Adam(learning_rate=0.001)  # use 'learning_rate', not 'lr'

METRICS = [
    tf.keras.metrics.AUC(name='auc'),
    tf.keras.metrics.BinaryAccuracy(name='accuracy'),
    tf.keras.metrics.Precision(name='precision'),
    tf.keras.metrics.Recall(name='recall'),
    # Add custom F1 score only if defined earlier
    # f1_score
]

model.compile(
    loss='categorical_crossentropy',
    optimizer=OPT,
    metrics=METRICS
)

# %%
from tensorflow.keras.callbacks import EarlyStopping

earlystopping = EarlyStopping(
    monitor='val_auc',
    mode='max',
    patience=15,
    verbose=1
)

callback_list = [earlystopping]

# %%
model_history=model.fit(train_dataset,
                        validation_data=valid_dataset,
                        epochs = 50,
                        callbacks = callback_list,
                        verbose = 1)
# Out:
# Epoch 1/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 235s 6s/step - accuracy: 0.7678 - auc: 0.8049 - loss: 1.2394 - precision: 0.5400 - recall: 0.4815 - val_accuracy: 0.7883 - val_auc: 0.8166 - val_loss: 1.5470 - val_precision: 0.5822 - val_recall: 0.5426
# Epoch 2/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 205s 5s/step - accuracy: 0.7840 - auc: 0.8258 - loss: 1.0655 - precision: 0.5791 - recall: 0.4984 - val_accuracy: 0.7996 - val_auc: 0.8346 - val_loss: 1.1006 - val_precision: 0.6176 - val_recall: 0.5215
# Epoch 3/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 230s 6s/step - accuracy: 0.8013 - auc: 0.8491 - loss: 0.9630 - precision: 0.6206 - recall: 0.5276 - val_accuracy: 0.8108 - val_auc: 0.8595 - val_loss: 0.9027 - val_precision: 0.6572 - val_recall: 0.5082
# Epoch 4/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 238s 6s/step - accuracy: 0.8058 - auc: 0.8590 - loss: 0.9014 - precision: 0.6325 - recall: 0.5330 - val_accuracy: 0.8184 - val_auc: 0.8701 - val_loss: 0.8414 - val_precision: 0.6874 - val_recall: 0.5020
# Epoch 5/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 233s 6s/step - accuracy: 0.8108 - auc: 0.8665 - loss: 0.8608 - precision: 0.6475 - recall: 0.5340 - val_accuracy: 0.8272 - val_auc: 0.8790 - val_loss: 0.8116 - val_precision: 0.7081 - val_recall: 0.5254
# Epoch 6/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 232s 6s/step - accuracy: 0.8259 - auc: 0.8842 - loss: 0.8029 - precision: 0.6793 - recall: 0.5754 - val_accuracy: 0.8272 - val_auc: 0.8787 - val_loss: 0.8075 - val_precision: 0.7112 - val_recall: 0.5199
# Epoch 7/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 213s 5s/step - accuracy: 0.8224 - auc: 0.8802 - loss: 0.8150 - precision: 0.6715 - recall: 0.5669 - val_accuracy: 0.8245 - val_auc: 0.8808 - val_loss: 0.8026 - val_precision: 0.7042 - val_recall: 0.5137
# Epoch 8/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 204s 5s/step - accuracy: 0.8384 - auc: 0.8960 - loss: 0.7565 - precision: 0.7088 - recall: 0.6002 - val_accuracy: 0.8339 - val_auc: 0.8930 - val_loss: 0.7563 - val_precision: 0.7200 - val_recall: 0.5489
# Epoch 9/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 204s 5s/step - accuracy: 0.8411 - auc: 0.9040 - loss: 0.7199 - precision: 0.7124 - recall: 0.6109 - val_accuracy: 0.8411 - val_auc: 0.8989 - val_loss: 0.7391 - val_precision: 0.7284 - val_recall: 0.5809
# Epoch 10/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 203s 5s/step - accuracy: 0.8378 - auc: 0.9011 - loss: 0.7327 - precision: 0.7036 - recall: 0.6069 - val_accuracy: 0.8432 - val_auc: 0.9010 - val_loss: 0.7282 - val_precision: 0.7354 - val_recall: 0.5825
# Epoch 11/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 203s 5s/step - accuracy: 0.8452 - auc: 0.9088 - loss: 0.6988 - precision: 0.7201 - recall: 0.6232 - val_accuracy: 0.8344 - val_auc: 0.8971 - val_loss: 0.7445 - val_precision: 0.7065 - val_recall: 0.5778
# Epoch 12/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 203s 5s/step - accuracy: 0.8523 - auc: 0.9154 - loss: 0.6763 - precision: 0.7378 - recall: 0.6353 - val_accuracy: 0.8393 - val_auc: 0.9007 - val_loss: 0.7306 - val_precision: 0.7265 - val_recall: 0.5731
# Epoch 13/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 204s 5s/step - accuracy: 0.8518 - auc: 0.9166 - loss: 0.6673 - precision: 0.7353 - recall: 0.6364 - val_accuracy: 0.8409 - val_auc: 0.9026 - val_loss: 0.7245 - val_precision: 0.7191 - val_recall: 0.5966
# Epoch 14/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 203s 5s/step - accuracy: 0.8600 - auc: 0.9199 - loss: 0.6552 - precision: 0.7513 - recall: 0.6576 - val_accuracy: 0.8348 - val_auc: 0.9020 - val_loss: 0.7258 - val_precision: 0.6998 - val_recall: 0.5942
# Epoch 15/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 203s 5s/step - accuracy: 0.8577 - auc: 0.9193 - loss: 0.6572 - precision: 0.7453 - recall: 0.6544 - val_accuracy: 0.8481 - val_auc: 0.9108 - val_loss: 0.6900 - val_precision: 0.7315 - val_recall: 0.6200
# Epoch 16/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 203s 5s/step - accuracy: 0.8598 - auc: 0.9227 - loss: 0.6293 - precision: 0.7332 - recall: 0.6573 - val_accuracy: 0.8536 - val_auc: 0.9169 - val_loss: 0.6689 - val_precision: 0.7413 - val_recall: 0.6364
# Epoch 17/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 203s 5s/step - accuracy: 0.8699 - auc: 0.9331 - loss: 0.6019 - precision: 0.7636 - recall: 0.6945 - val_accuracy: 0.8432 - val_auc: 0.9089 - val_loss: 0.6929 - val_precision: 0.7198 - val_recall: 0.6106
# Epoch 18/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 203s 5s/step - accuracy: 0.8643 - auc: 0.9283 - loss: 0.6196 - precision: 0.7526 - recall: 0.6812 - val_accuracy: 0.8440 - val_auc: 0.9045 - val_loss: 0.7339 - val_precision: 0.7192 - val_recall: 0.6169
# Epoch 19/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 203s 5s/step - accuracy: 0.8674 - auc: 0.9278 - loss: 0.6269 - precision: 0.7598 - recall: 0.6863 - val_accuracy: 0.8415 - val_auc: 0.9116 - val_loss: 0.6883 - val_precision: 0.7104 - val_recall: 0.6177
# Epoch 20/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 203s 5s/step - accuracy: 0.8705 - auc: 0.9330 - loss: 0.6024 - precision: 0.7656 - recall: 0.6944 - val_accuracy: 0.8530 - val_auc: 0.9180 - val_loss: 0.6745 - val_precision: 0.7313 - val_recall: 0.6513
# Epoch 21/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 203s 5s/step - accuracy: 0.8781 - auc: 0.9340 - loss: 0.6027 - precision: 0.7759 - recall: 0.7200 - val_accuracy: 0.8442 - val_auc: 0.9105 - val_loss: 0.6969 - val_precision: 0.7121 - val_recall: 0.6325
# Epoch 22/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 203s 5s/step - accuracy: 0.8717 - auc: 0.9349 - loss: 0.5925 - precision: 0.7644 - recall: 0.7036 - val_accuracy: 0.8632 - val_auc: 0.9243 - val_loss: 0.6482 - val_precision: 0.7485 - val_recall: 0.6818
# Epoch 23/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 203s 5s/step - accuracy: 0.8791 - auc: 0.9427 - loss: 0.5549 - precision: 0.7824 - recall: 0.7150 - val_accuracy: 0.8556 - val_auc: 0.9162 - val_loss: 0.6807 - val_precision: 0.7356 - val_recall: 0.6591
# Epoch 24/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 202s 5s/step - accuracy: 0.8800 - auc: 0.9422 - loss: 0.5580 - precision: 0.7819 - recall: 0.7212 - val_accuracy: 0.8514 - val_auc: 0.9177 - val_loss: 0.6744 - val_precision: 0.7266 - val_recall: 0.6505
# Epoch 25/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 202s 5s/step - accuracy: 0.8810 - auc: 0.9448 - loss: 0.5444 - precision: 0.7820 - recall: 0.7265 - val_accuracy: 0.8643 - val_auc: 0.9279 - val_loss: 0.6238 - val_precision: 0.7559 - val_recall: 0.6755
# Epoch 26/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 203s 5s/step - accuracy: 0.8858 - auc: 0.9466 - loss: 0.5339 - precision: 0.7902 - recall: 0.7396 - val_accuracy: 0.8542 - val_auc: 0.9168 - val_loss: 0.6751 - val_precision: 0.7319 - val_recall: 0.6575
# Epoch 27/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 202s 5s/step - accuracy: 0.8814 - auc: 0.9423 - loss: 0.5602 - precision: 0.7840 - recall: 0.7254 - val_accuracy: 0.8663 - val_auc: 0.9274 - val_loss: 0.6361 - val_precision: 0.7558 - val_recall: 0.6873
# Epoch 28/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 202s 5s/step - accuracy: 0.8791 - auc: 0.9423 - loss: 0.5596 - precision: 0.7764 - recall: 0.7253 - val_accuracy: 0.8685 - val_auc: 0.9278 - val_loss: 0.6339 - val_precision: 0.7590 - val_recall: 0.6943
# Epoch 29/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 203s 5s/step - accuracy: 0.8912 - auc: 0.9520 - loss: 0.5085 - precision: 0.8009 - recall: 0.7514 - val_accuracy: 0.8587 - val_auc: 0.9230 - val_loss: 0.6601 - val_precision: 0.7430 - val_recall: 0.6646
# Epoch 30/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 202s 5s/step - accuracy: 0.8851 - auc: 0.9498 - loss: 0.5335 - precision: 0.7752 - recall: 0.7295 - val_accuracy: 0.8696 - val_auc: 0.9289 - val_loss: 0.6255 - val_precision: 0.7611 - val_recall: 0.6974
# Epoch 31/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 203s 5s/step - accuracy: 0.8897 - auc: 0.9522 - loss: 0.5055 - precision: 0.7965 - recall: 0.7507 - val_accuracy: 0.8618 - val_auc: 0.9283 - val_loss: 0.6205 - val_precision: 0.7474 - val_recall: 0.6755
# Epoch 32/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 202s 5s/step - accuracy: 0.8907 - auc: 0.9499 - loss: 0.5218 - precision: 0.8009 - recall: 0.7489 - val_accuracy: 0.8630 - val_auc: 0.9261 - val_loss: 0.6387 - val_precision: 0.7474 - val_recall: 0.6826
# Epoch 33/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 202s 5s/step - accuracy: 0.8888 - auc: 0.9521 - loss: 0.5065 - precision: 0.7951 - recall: 0.7477 - val_accuracy: 0.8655 - val_auc: 0.9273 - val_loss: 0.6486 - val_precision: 0.7506 - val_recall: 0.6919
# Epoch 34/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 202s 5s/step - accuracy: 0.8980 - auc: 0.9550 - loss: 0.4923 - precision: 0.8123 - recall: 0.7699 - val_accuracy: 0.8616 - val_auc: 0.9295 - val_loss: 0.6262 - val_precision: 0.7442 - val_recall: 0.6802
# Epoch 35/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 203s 5s/step - accuracy: 0.8915 - auc: 0.9543 - loss: 0.4961 - precision: 0.8016 - recall: 0.7524 - val_accuracy: 0.8643 - val_auc: 0.9277 - val_loss: 0.6391 - val_precision: 0.7485 - val_recall: 0.6888
# Epoch 36/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 203s 5s/step - accuracy: 0.8952 - auc: 0.9568 - loss: 0.4808 - precision: 0.8081 - recall: 0.7614 - val_accuracy: 0.8657 - val_auc: 0.9283 - val_loss: 0.6335 - val_precision: 0.7556 - val_recall: 0.6841
# Epoch 37/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 203s 5s/step - accuracy: 0.9002 - auc: 0.9580 - loss: 0.4731 - precision: 0.8197 - recall: 0.7701 - val_accuracy: 0.8731 - val_auc: 0.9376 - val_loss: 0.5778 - val_precision: 0.7683 - val_recall: 0.7052
# Epoch 38/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 202s 5s/step - accuracy: 0.9042 - auc: 0.9605 - loss: 0.4608 - precision: 0.8263 - recall: 0.7811 - val_accuracy: 0.8724 - val_auc: 0.9351 - val_loss: 0.6033 - val_precision: 0.7626 - val_recall: 0.7107
# Epoch 39/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 203s 5s/step - accuracy: 0.9102 - auc: 0.9637 - loss: 0.4421 - precision: 0.8380 - recall: 0.7942 - val_accuracy: 0.8714 - val_auc: 0.9318 - val_loss: 0.6260 - val_precision: 0.7603 - val_recall: 0.7091
# Epoch 40/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 203s 5s/step - accuracy: 0.9048 - auc: 0.9636 - loss: 0.4411 - precision: 0.8238 - recall: 0.7879 - val_accuracy: 0.8714 - val_auc: 0.9368 - val_loss: 0.5976 - val_precision: 0.7585 - val_recall: 0.7123
# Epoch 41/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 202s 5s/step - accuracy: 0.9070 - auc: 0.9601 - loss: 0.4657 - precision: 0.8291 - recall: 0.7910 - val_accuracy: 0.8812 - val_auc: 0.9403 - val_loss: 0.5754 - val_precision: 0.7826 - val_recall: 0.7263
# Epoch 42/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 202s 5s/step - accuracy: 0.9066 - auc: 0.9631 - loss: 0.4450 - precision: 0.8275 - recall: 0.7913 - val_accuracy: 0.8714 - val_auc: 0.9321 - val_loss: 0.6315 - val_precision: 0.7629 - val_recall: 0.7045
# Epoch 43/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 203s 5s/step - accuracy: 0.9142 - auc: 0.9656 - loss: 0.4322 - precision: 0.8426 - recall: 0.8078 - val_accuracy: 0.8647 - val_auc: 0.9322 - val_loss: 0.6241 - val_precision: 0.7468 - val_recall: 0.6943
# Epoch 44/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 203s 5s/step - accuracy: 0.9104 - auc: 0.9650 - loss: 0.4326 - precision: 0.8347 - recall: 0.8000 - val_accuracy: 0.8782 - val_auc: 0.9397 - val_loss: 0.5863 - val_precision: 0.7729 - val_recall: 0.7263
# Epoch 45/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 203s 5s/step - accuracy: 0.9074 - auc: 0.9640 - loss: 0.4400 - precision: 0.8262 - recall: 0.7975 - val_accuracy: 0.8796 - val_auc: 0.9402 - val_loss: 0.5856 - val_precision: 0.7746 - val_recall: 0.7310
# Epoch 46/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 203s 5s/step - accuracy: 0.9206 - auc: 0.9714 - loss: 0.3906 - precision: 0.8517 - recall: 0.8263 - val_accuracy: 0.8747 - val_auc: 0.9389 - val_loss: 0.5969 - val_precision: 0.7615 - val_recall: 0.7263
# Epoch 47/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 202s 5s/step - accuracy: 0.9069 - auc: 0.9500 - loss: 0.4655 - precision: 0.8153 - recall: 0.7819 - val_accuracy: 0.8819 - val_auc: 0.9431 - val_loss: 0.5652 - val_precision: 0.7796 - val_recall: 0.7357
# Epoch 48/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 202s 5s/step - accuracy: 0.9174 - auc: 0.9692 - loss: 0.4049 - precision: 0.8467 - recall: 0.8175 - val_accuracy: 0.8710 - val_auc: 0.9357 - val_loss: 0.6112 - val_precision: 0.7568 - val_recall: 0.7131
# Epoch 49/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 203s 5s/step - accuracy: 0.9156 - auc: 0.9679 - loss: 0.4161 - precision: 0.8433 - recall: 0.8134 - val_accuracy: 0.8890 - val_auc: 0.9429 - val_loss: 0.5770 - val_precision: 0.7912 - val_recall: 0.7553
# Epoch 50/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 202s 5s/step - accuracy: 0.9148 - auc: 0.9684 - loss: 0.4102 - precision: 0.8410 - recall: 0.8130 - val_accuracy: 0.8804 - val_auc: 0.9440 - val_loss: 0.5643 - val_precision: 0.7754 - val_recall: 0.7342

# %%
model.save('dense_alzehimermodel.keras')  # saves entire model

# %%
from tensorflow.keras.models import load_model

model = load_model('dense_alzehimermodel.keras')

# %%
history = model.fit(
    train_dataset,
    validation_data=valid_dataset,
    epochs=15,
    callbacks=callback_list  # optional
)
# Out:
# Epoch 1/15
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 246s 6s/step - accuracy: 0.9158 - auc: 0.9710 - loss: 0.3919 - precision: 0.8434 - recall: 0.8143 - val_accuracy: 0.8792 - val_auc: 0.9383 - val_loss: 0.5996 - val_precision: 0.7729 - val_recall: 0.7318
# Epoch 2/15
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 212s 5s/step - accuracy: 0.9205 - auc: 0.9713 - loss: 0.3925 - precision: 0.8518 - recall: 0.8257 - val_accuracy: 0.8815 - val_auc: 0.9432 - val_loss: 0.5704 - val_precision: 0.7770 - val_recall: 0.7381
# Epoch 3/15
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 216s 5s/step - accuracy: 0.9181 - auc: 0.9713 - loss: 0.3924 - precision: 0.8489 - recall: 0.8181 - val_accuracy: 0.8761 - val_auc: 0.9380 - val_loss: 0.6114 - val_precision: 0.7654 - val_recall: 0.7271
# Epoch 4/15
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 211s 5s/step - accuracy: 0.9213 - auc: 0.9715 - loss: 0.3891 - precision: 0.8522 - recall: 0.8288 - val_accuracy: 0.8800 - val_auc: 0.9419 - val_loss: 0.5787 - val_precision: 0.7710 - val_recall: 0.7396
# Epoch 5/15
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 218s 5s/step - accuracy: 0.9245 - auc: 0.9749 - loss: 0.3669 - precision: 0.8595 - recall: 0.8344 - val_accuracy: 0.8878 - val_auc: 0.9465 - val_loss: 0.5580 - val_precision: 0.7887 - val_recall: 0.7529
# Epoch 6/15
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 227s 6s/step - accuracy: 0.9241 - auc: 0.9759 - loss: 0.3598 - precision: 0.8579 - recall: 0.8347 - val_accuracy: 0.8833 - val_auc: 0.9472 - val_loss: 0.5395 - val_precision: 0.7832 - val_recall: 0.7373
# Epoch 7/15
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 231s 6s/step - accuracy: 0.9232 - auc: 0.9738 - loss: 0.3761 - precision: 0.8572 - recall: 0.8312 - val_accuracy: 0.8831 - val_auc: 0.9430 - val_loss: 0.5831 - val_precision: 0.7789 - val_recall: 0.7435
# Epoch 8/15
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 224s 5s/step - accuracy: 0.9201 - auc: 0.9707 - loss: 0.3935 - precision: 0.8501 - recall: 0.8261 - val_accuracy: 0.8941 - val_auc: 0.9517 - val_loss: 0.5167 - val_precision: 0.8033 - val_recall: 0.7631
# Epoch 9/15
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 203s 5s/step - accuracy: 0.9251 - auc: 0.9765 - loss: 0.3536 - precision: 0.8594 - recall: 0.8372 - val_accuracy: 0.8923 - val_auc: 0.9488 - val_loss: 0.5384 - val_precision: 0.7984 - val_recall: 0.7615
# Epoch 10/15
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 212s 5s/step - accuracy: 0.9262 - auc: 0.9724 - loss: 0.3839 - precision: 0.8625 - recall: 0.8385 - val_accuracy: 0.8810 - val_auc: 0.9426 - val_loss: 0.5825 - val_precision: 0.7732 - val_recall: 0.7412
# Epoch 11/15
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 223s 5s/step - accuracy: 0.9238 - auc: 0.9750 - loss: 0.3634 - precision: 0.8567 - recall: 0.8346 - val_accuracy: 0.8853 - val_auc: 0.9437 - val_loss: 0.5849 - val_precision: 0.7818 - val_recall: 0.7506
# Epoch 12/15
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 232s 6s/step - accuracy: 0.9183 - auc: 0.9725 - loss: 0.3828 - precision: 0.8451 - recall: 0.8244 - val_accuracy: 0.8837 - val_auc: 0.9437 - val_loss: 0.5713 - val_precision: 0.7836 - val_recall: 0.7389
# Epoch 13/15
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 235s 6s/step - accuracy: 0.9262 - auc: 0.9754 - loss: 0.3602 - precision: 0.8628 - recall: 0.8380 - val_accuracy: 0.8886 - val_auc: 0.9462 - val_loss: 0.5606 - val_precision: 0.7903 - val_recall: 0.7545
# Epoch 14/15
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 208s 5s/step - accuracy: 0.9286 - auc: 0.9761 - loss: 0.3552 - precision: 0.8666 - recall: 0.8444 - val_accuracy: 0.8974 - val_auc: 0.9515 - val_loss: 0.5258 - val_precision: 0.8090 - val_recall: 0.7717
# Epoch 15/15
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 204s 5s/step - accuracy: 0.9341 - auc: 0.9782 - loss: 0.3391 - precision: 0.8780 - recall: 0.8551 - val_accuracy: 0.8966 - val_auc: 0.9532 - val_loss: 0.5183 - val_precision: 0.8049 - val_recall: 0.7740

# %%
# Summarize history for loss

plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left', bbox_to_anchor=(1,1))
plt.show()

# %%
# Summarize history for loss

plt.plot(model_history.history['auc'])
plt.plot(model_history.history['val_auc'])
plt.title('Model AUC')
plt.ylabel('AUC')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left', bbox_to_anchor=(1,1))
plt.show()

# %%
import tensorflow as tf  # Make sure this is at the top

OPT = tf.keras.optimizers.Adam(learning_rate=0.001)

METRICS = [
    tf.keras.metrics.AUC(name='auc'),
    tf.keras.metrics.CategoricalAccuracy(name='accuracy'),
    tf.keras.metrics.Precision(name='precision'),
    tf.keras.metrics.Recall(name='recall'),
    # Add this only if you've defined it somewhere
    # f1_score,
]

model.compile(
    loss='categorical_crossentropy',
    optimizer=OPT,
    metrics=METRICS
)

# %%
# Test Data 
test_dataset  = test_datagen.flow_from_directory(directory = r"C:\Users\Shubhankar\Downloads\Alzheimers disease dataset\Alzheimers disease dataset\Alzheimer's dataset\OriginalDataset",
                                                 target_size = (224,224),
                                                 class_mode = 'categorical')
# Out:
# Found 6400 images belonging to 4 classes.

# %%
# Evaluating Loss and AUC

model.evaluate(test_dataset)
# Out:
# c:\Users\Shubhankar\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 345s 2s/step - accuracy: 0.8636 - auc: 0.9745 - loss: 0.3705 - precision: 0.8714 - recall: 0.8547
# [0.3617885112762451,
#  0.9759031534194946,
#  0.862500011920929,
#  0.8702642321586609,
#  0.8542187213897705]

# %%
#for Non demented class
dic = test_dataset.class_indices
idc = {v: k for k, v in dic.items()}

# Image path
img_path = r"C:\Users\Shubhankar\Downloads\Alzheimers disease dataset\Alzheimers disease dataset\Alzheimer's dataset\OriginalDataset\NonDemented\nonDem989.jpg"
actual_class = "NonDemented"
filename = os.path.basename(img_path)

# Load and preprocess image
img = load_img(img_path, target_size=(224, 224, 3))
img_array = img_to_array(img) / 255.0
img_array = np.expand_dims(img_array, axis=0)

# Predict
pred = model.predict(img_array)
predicted_index = np.argmax(pred, axis=1)[0]
predicted_class = idc[predicted_index]
probability = round(np.max(pred) * 100, 2)

# Show image
plt.imshow(img)
plt.axis('off')
plt.title(f"Image: {filename}")
plt.show()

# Print result
print(f"🖼️ Image Name     : {filename}")
print(f"✅ Actual Class   : {actual_class}")
print(f"🔮 Predicted Class: {predicted_class}")
print(f"📊 Confidence     : {probability}%")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step
# 🖼️ Image Name     : nonDem989.jpg
# ✅ Actual Class   : NonDemented
# 🔮 Predicted Class: NonDemented
# 📊 Confidence     : 94.9%

# %%
# for mild demented
dic = test_dataset.class_indices
idc = {v: k for k, v in dic.items()}

# Image path
img_path = r"C:\Users\Shubhankar\Downloads\Alzheimers disease dataset\Alzheimers disease dataset\Alzheimer's dataset\OriginalDataset\MildDemented\mildDem704.jpg"
actual_class = "MildDemented"
filename = os.path.basename(img_path)

# Load and preprocess image
img = load_img(img_path, target_size=(224, 224, 3))
img_array = img_to_array(img) / 255.0
img_array = np.expand_dims(img_array, axis=0)

# Predict
pred = model.predict(img_array)
predicted_index = np.argmax(pred, axis=1)[0]
predicted_class = idc[predicted_index]
probability = round(np.max(pred) * 100, 2)

# Show image
plt.imshow(img)
plt.axis('off')
plt.title(f"Image: {filename}")
plt.show()

# Print result
print(f"🖼️ Image Name     : {filename}")
print(f"✅ Actual Class   : {actual_class}")
print(f"🔮 Predicted Class: {predicted_class}")
print(f"📊 Confidence     : {probability}%")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 🖼️ Image Name     : mildDem704.jpg
# ✅ Actual Class   : MildDemented
# 🔮 Predicted Class: MildDemented
# 📊 Confidence     : 99.28%

# %%
# for moderated demented
dic = test_dataset.class_indices
idc = {v: k for k, v in dic.items()}

# Image path
img_path = r"C:\Users\Shubhankar\Downloads\archive (3)\Alzheimer_MRI_4_classes_dataset\ModerateDemented\3 (2).jpg"
actual_class = "ModeratedDemented"
filename = os.path.basename(img_path)

# Load and preprocess image
img = load_img(img_path, target_size=(224, 224, 3))
img_array = img_to_array(img) / 255.0
img_array = np.expand_dims(img_array, axis=0)

# Predict
pred = model.predict(img_array)
predicted_index = np.argmax(pred, axis=1)[0]
predicted_class = idc[predicted_index]
probability = round(np.max(pred) * 100, 2)

# Show image
plt.imshow(img)
plt.axis('off')
plt.title(f"Image: {filename}")
plt.show()

# Print result
print(f"🖼️ Image Name     : {filename}")
print(f"✅ Actual Class   : {actual_class}")
print(f"🔮 Predicted Class: {predicted_class}")
print(f"📊 Confidence     : {probability}%")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step
# 🖼️ Image Name     : 3 (2).jpg
# ✅ Actual Class   : ModeratedDemented
# 🔮 Predicted Class: ModerateDemented
# 📊 Confidence     : 100.0%

# %%
# for very mild demented
dic = test_dataset.class_indices
idc = {v: k for k, v in dic.items()}

# Image path
img_path = r"C:\Users\Shubhankar\Downloads\Alzheimers disease dataset\Alzheimers disease dataset\Alzheimer's dataset\OriginalDataset\VeryMildDemented\verymildDem981.jpg"
actual_class = "veymilddDemented"
filename = os.path.basename(img_path)

# Load and preprocess image
img = load_img(img_path, target_size=(224, 224, 3))
img_array = img_to_array(img) / 255.0
img_array = np.expand_dims(img_array, axis=0)

# Predict
pred = model.predict(img_array)
predicted_index = np.argmax(pred, axis=1)[0]
predicted_class = idc[predicted_index]
probability = round(np.max(pred) * 100, 2)

# Show image
plt.imshow(img)
plt.axis('off')
plt.title(f"Image: {filename}")
plt.show()

# Print result
print(f"🖼️ Image Name     : {filename}")
print(f"✅ Actual Class   : {actual_class}")
print(f"🔮 Predicted Class: {predicted_class}")
print(f"📊 Confidence     : {probability}%")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step
# 🖼️ Image Name     : verymildDem981.jpg
# ✅ Actual Class   : veymilddDemented
# 🔮 Predicted Class: VeryMildDemented
# 📊 Confidence     : 87.51%

# %%
#Confusion Matrix
model.load_weights('dense_alzehimermodel.keras')
true_classes = test_dataset.classes
class_indices = test_dataset.class_indices
class_indices = dict((v,k) for k,v in class_indices.items())

preds = model.predict(test_dataset)
pred_classes = np.argmax(preds, axis=1)
# Out:
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 293s 1s/step

# %%
# Get the names of the ten classes
class_names = test_dataset.class_indices.keys()

def plot_heatmap(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    sns.heatmap(
        cm, 
        annot=True, 
        square=True, 
        fmt='d', 
        cmap=plt.cm.Blues,
        cbar=False,
    )

plt.figure()
plot_heatmap(true_classes, pred_classes)    

plt.show()

# %%
model.save('dense_alzehimermodel.keras')
